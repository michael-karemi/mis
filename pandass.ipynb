# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-karemi/my-ishh/blob/main/pandass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
days = pd.Series(['mon', 'tue', 'wed', 'thur', 'fri'])
print(days)
# Out:
# 0     mon
# 1     tue
# 2     wed
# 3    thur
# 4     fri
# dtype: object

# %%
days_list = np.array(['mon', 'tue', 'wed', 'thur', 'fri'])
numpy_days = pd.Series(days_list)
numpy_days
# Out:
# 0     mon
# 1     tue
# 2     wed
# 3    thur
# 4     fri
# dtype: object

# %%
days1 = pd.Series({'a':'Mon', 'b':'Tue', 'c':'Wed'})
days0 = pd.Series(['Mon', 'Tuue', 'Wed'], index = ['a', 'b', 'c'])

days0['c']
# Out:
# 'Wed'

# %%
days[4]
# Out:
# 'fri'

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# No charts were generated by quickchart

# %%
#creating a dataframe from a dictionary
dfdict = {'Country':['Kenya', 'Tanzania', 'Ethiopia'],
          'Capital':['Nairobi', 'Dar-es-saalam', 'Addis Ababa'],
          'Population':[10000, 560000, 8962244],
          'Age':[45, 56, 89]
          }
dfdict
# Out:
# {'Country': ['Kenya', 'Tanzania', 'Ethiopia'],
#  'Capital': ['Nairobi', 'Dar-es-saalam', 'Addis Ababa'],
#  'Population': [10000, 560000, 8962244],
#  'Age': [45, 56, 89]}

# %%
dff = pd.DataFrame(dfdict, index = [2, 4, 6, 8])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-eda0a5703f23> in <cell line: 1>()
# ----> 1 dff = pd.DataFrame(dfdict, index = [2, 4, 6, 8])
#       2 dff
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# ...

# %%
calories = [400, 200, 300, 400]
var = pd.Series(calories, index = ['day1', 'day2', 'day3', 'day4'])
var.[]
# Out:
# 200

# %%
var.loc['day1']
# Out:
# 400

# %%
var.values
# Out:
# array([400, 200, 300, 400])

# %%
foods = ['mukimo', 'ugali', 'githeri', 'pilau']
difu = pd.DataFrame(foods)
difu
# Out:
#          0
# 0   mukimo
# 1    ugali
# 2  githeri
# 3    pilau

# %%
arrs = np.array([[1, 1], [1, 4, 9, 16, 25]])
ray = arrs.reshape((5, 2))
ray
# Out:
# <ipython-input-50-1aa7323e54d8>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arrs = np.array([[1, 1], [1, 4, 9, 16, 25]])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-1aa7323e54d8> in <cell line: 2>()
#       1 arrs = np.array([[1, 1], [1, 4, 9, 16, 25]])
# ----> 2 ray = arrs.reshape((5, 2))
#       3 ray
#
# ValueError: cannot reshape array of size 2 into shape (5,2)

# %%
data = pd.read_csv('pand/iris_dataset.csv')
data.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
subdf = data.describe(include = 'all')

# %%
data.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
subdf.dropna()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count              150.0             150.0              150.0
#
#        petal width (cm) target
# count             150.0    150

# %%
subdf2 = subdf.drop(['target'], axis = 1)
subdf2.dropna()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
